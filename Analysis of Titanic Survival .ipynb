# %% [markdown]
# Titanic Survival

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,BaggingClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.naive_bayes import GaussianNB
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython import display
display.Image("Titanic.png")

# %%
Train=pd.read_csv(r'Train.csv')
Train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
Test=pd.read_csv(r'Test.csv')
Test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
Train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
combine = [Train,Test]

# %%
print(Train.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %%
Train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
Train.info()
print('_'*45)
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# _____________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
Test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
Train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Train_num = Train.select_dtypes(["int64", "float64"])
Train_cat = Train.select_dtypes(object)

# %%
Train_cat
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
Train_num
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
def Barchart(char):
    Survive=Train[Train['Survived']==1][char].value_counts()
    Dead=Train[Train['Survived']==0][char].value_counts()
    df1=pd.DataFrame([Survive,Dead])
    df1.index=['Survived','Dead']
    df1.plot(kind='bar',stacked=True,figsize=(8,8))

# %%
Train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Data Visualisation

# %%
Barchart('Sex')
print('Survived: \n', Train[Train['Survived']==1]['Sex'].value_counts())
print('Dead: \n', Train[Train['Survived']==0]['Sex'].value_counts())
# Out:
# Survived:
#  Sex
# female    233
# male      109
# Name: count, dtype: int64
# Dead:
#  Sex
# male      468
# female     81
# Name: count, dtype: int64

# %%
Barchart('Pclass')
print('Survived: \n', Train[Train['Survived']==1]['Pclass'].value_counts())
print('Dead: \n', Train[Train['Survived']==0]['Pclass'].value_counts())
# Out:
# Survived:
#  Pclass
# 1    136
# 3    119
# 2     87
# Name: count, dtype: int64
# Dead:
#  Pclass
# 3    372
# 2     97
# 1     80
# Name: count, dtype: int64

# %%
Barchart('SibSp')
print('Survived: \n', Train[Train['Survived']==1]['SibSp'].value_counts())
print('Dead: \n', Train[Train['Survived']==0]['SibSp'].value_counts())
# Out:
# Survived:
#  SibSp
# 0    210
# 1    112
# 2     13
# 3      4
# 4      3
# Name: count, dtype: int64
# Dead:
#  SibSp
# 0    398
# 1     97
# 4     15
# 2     15
# 3     12
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
Barchart('Parch')
print('Survived: \n', Train[Train['Survived']==1]['Parch'].value_counts())
print('Dead: \n', Train[Train['Survived']==0]['Parch'].value_counts())
# Out:
# Survived:
#  Parch
# 0    233
# 1     65
# 2     40
# 3      3
# 5      1
# Name: count, dtype: int64
# Dead:
#  Parch
# 0    445
# 1     53
# 2     40
# 5      4
# 4      4
# 3      2
# 6      1
# Name: count, dtype: int64

# %%
Barchart('Embarked')
print('Survived: \n', Train[Train['Survived']==1]['Embarked'].value_counts())
print('Dead: \n', Train[Train['Survived']==0]['Embarked'].value_counts())
# Out:
# Survived:
#  Embarked
# S    217
# C     93
# Q     30
# Name: count, dtype: int64
# Dead:
#  Embarked
# S    427
# C     75
# Q     47
# Name: count, dtype: int64

# %% [markdown]
# Feature Engineering

# %%
for Dataset in combine:
    Dataset['Title']=Dataset.Name.str.extract(' ([A-Za-z]+)\.')
pd.crosstab(Train['Title'], Train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
Train['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
Train['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %% [markdown]
# Title Mapping

# %%
for Dataset in combine:
    Dataset['Title']=Dataset['Title'].replace(['Master','Dr','Rev','Mlle','Major','Col','Countess','Capt','Ms','Sir','Lady',\
                                             'Mme','Don','Jonkheer'],'Other')
Train['Title'].value_counts()
# Out:
# Title
# Mr       517
# Miss     182
# Mrs      125
# Other     67
# Name: count, dtype: int64

# %%
Title_map={'Mr':1,'Miss':2,'Mrs':3,'Other':4}
for Dataset in combine:
    Dataset['Title'] = Dataset["Title"].map(Title_map)

# %%
Dataset.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q    1.0
# 1  47.0      1      0   363272   7.0000   NaN        S    3.0
# 2  62.0      0      0   240276   9.6875   NaN        Q    1.0
# 3  27.0      0      0   315154   8.6625   NaN        S    1.0
# 4  22.0      1      1  3101298  12.2875   NaN        S    3.0

# %%
Train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      3
# 2      0  STON/O2. 3101282   7.9250   NaN        S      2
# 3      0            113803  53.1000  C123        S      3
# 4      0            373450   8.0500   NaN        S      1

# %%
Barchart('Title')

# %%
Sex_map={'male':0,'female':1}
for Dataset in combine:
    Dataset['Sex'] = Dataset['Sex'].map(Sex_map)

# %%
Train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      1
# 1          PC 17599  71.2833   C85        C      3
# 2  STON/O2. 3101282   7.9250   NaN        S      2
# 3            113803  53.1000  C123        S      3
# 4            373450   8.0500   NaN        S      1

# %%
Barchart('Sex')

# %%
# delete unnecessary feature from dataset
Train.drop('Name', axis=1, inplace=True)
Test.drop('Name', axis=1, inplace=True)

# %%
Test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    0  34.5      0      0   330911   7.8292   NaN
# 1          893       3    1  47.0      1      0   363272   7.0000   NaN
# 2          894       2    0  62.0      0      0   240276   9.6875   NaN
# 3          895       3    0  27.0      0      0   315154   8.6625   NaN
# 4          896       3    1  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q    1.0
# 1        S    3.0
# 2        Q    1.0
# 3        S    1.0
# 4        S    3.0

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Title        891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.7+ KB

# %%
Train["Age"].fillna(Train.groupby("Title")["Age"].transform("median"), inplace= True)
Test["Age"].fillna(Test.groupby('Title')['Age'].transform("median"), inplace= True)

# %%
Train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# 5             6         0       3    0  30.0      0      0            330877
# 6             7         0       1    0  54.0      0      0             17463
# 7             8         0       3    0   2.0      3      1            349909
# 8             9         1       3    1  27.0      0      2            347742
# 9            10         1       2    1  14.0      1      0            237736
# 10           11         1       3    1   4.0      1      1           PP 9549
# 11           12         1       1    1  58.0      0      0            113783
# 12           13         0       3    0  20.0      0      0         A/5. 2151
# 13           14         0       3    0  39.0      1      5            347082
# 14           15         0       3    1  14.0      0      0            350406
# 15           16         1       2    1  55.0      0      0            248706
# 16           17         0       3    0   2.0      4      1            382652
# 17           18         1       2    0  30.0      0      0            244373
# 18           19         0       3    1  31.0      1      0            345763
# 19           20         1       3    1  35.0      0      0              2649
# 20           21         0       2    0  35.0      0      0            239865
# 21           22         1       2    0  34.0      0      0            248698
# 22           23         1       3    1  15.0      0      0            330923
# 23           24         1       1    0  28.0      0      0            113788
# 24           25         0       3    1   8.0      3      1            349909
# 25           26         1       3    1  38.0      1      5            347077
# 26           27         0       3    0  30.0      0      0              2631
# 27           28         0       1    0  19.0      3      2             19950
# 28           29         1       3    1  21.0      0      0            330959
# 29           30         0       3    0  30.0      0      0            349216
# 30           31         0       1    0  40.0      0      0          PC 17601
# 31           32         1       1    1  35.0      1      0          PC 17569
# 32           33         1       3    1  21.0      0      0            335677
# 33           34         0       2    0  66.0      0      0        C.A. 24579
# 34           35         0       1    0  28.0      1      0          PC 17604
# 35           36         0       1    0  42.0      1      0            113789
# 36           37         1       3    0  30.0      0      0              2677
# 37           38         0       3    0  21.0      0      0        A./5. 2152
# 38           39         0       3    1  18.0      2      0            345764
# 39           40         1       3    1  14.0      1      0              2651
# 40           41         0       3    1  40.0      1      0              7546
# 41           42         0       2    1  27.0      1      0             11668
# 42           43         0       3    0  30.0      0      0            349253
# 43           44         1       2    1   3.0      1      2     SC/Paris 2123
# 44           45         1       3    1  19.0      0      0            330958
# 45           46         0       3    0  30.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  30.0      1      0            370371
# 47           48         1       3    1  21.0      0      0             14311
# 48           49         0       3    0  30.0      2      0              2662
# 49           50         0       3    1  18.0      1      0            349237
#
#         Fare        Cabin Embarked  Title
# 0     7.2500          NaN        S      1
# 1    71.2833          C85        C      3
# 2     7.9250          NaN        S      2
# 3    53.1000         C123        S      3
# 4     8.0500          NaN        S      1
# 5     8.4583          NaN        Q      1
# 6    51.8625          E46        S      1
# 7    21.0750          NaN        S      4
# 8    11.1333          NaN        S      3
# 9    30.0708          NaN        C      3
# 10   16.7000           G6        S      2
# 11   26.5500         C103        S      2
# 12    8.0500          NaN        S      1
# 13   31.2750          NaN        S      1
# 14    7.8542          NaN        S      2
# 15   16.0000          NaN        S      3
# 16   29.1250          NaN        Q      4
# 17   13.0000          NaN        S      1
# 18   18.0000          NaN        S      3
# 19    7.2250          NaN        C      3
# 20   26.0000          NaN        S      1
# 21   13.0000          D56        S      1
# 22    8.0292          NaN        Q      2
# 23   35.5000           A6        S      1
# 24   21.0750          NaN        S      2
# 25   31.3875          NaN        S      3
# 26    7.2250          NaN        C      1
# 27  263.0000  C23 C25 C27        S      1
# 28    7.8792          NaN        Q      2
# 29    7.8958          NaN        S      1
# 30   27.7208          NaN        C      4
# 31  146.5208          B78        C      3
# 32    7.7500          NaN        Q      2
# 33   10.5000          NaN        S      1
# 34   82.1708          NaN        C      1
# 35   52.0000          NaN        S      1
# 36    7.2292          NaN        C      1
# 37    8.0500          NaN        S      1
# 38   18.0000          NaN        S      2
# 39   11.2417          NaN        C      2
# 40    9.4750          NaN        S      3
# 41   21.0000          NaN        S      3
# 42    7.8958          NaN        C      1
# 43   41.5792          NaN        C      2
# 44    7.8792          NaN        Q      2
# 45    8.0500          NaN        S      1
# 46   15.5000          NaN        Q      1
# 47    7.7500          NaN        Q      2
# 48   21.6792          NaN        C      1
# 49   17.8000          NaN        S      3

# %%
grid = sns.FacetGrid(Train, row='Pclass', col='Sex', aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()

# %%
Train['AgeBand'] = pd.cut(Train['Age'], 5)
Train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean()
# Out:
#             AgeBand  Survived
# 0    (0.34, 16.336]  0.542857
# 1  (16.336, 32.252]  0.327345
# 2  (32.252, 48.168]  0.439024
# 3  (48.168, 64.084]  0.434783
# 4    (64.084, 80.0]  0.090909

# %%
for Dataset in combine:
    Dataset.loc[Dataset['Age']<=16, 'Age']=0
    Dataset.loc[(Dataset['Age']>16) & (Dataset['Age']<=32), 'Age']=1
    Dataset.loc[(Dataset['Age']>32) & (Dataset['Age']<=48), 'Age']=2
    Dataset.loc[Dataset['Age']>48, 'Age']=3
Train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title           AgeBand
# 0   7.2500   NaN        S      1  (16.336, 32.252]
# 1  71.2833   C85        C      3  (32.252, 48.168]
# 2   7.9250   NaN        S      2  (16.336, 32.252]
# 3  53.1000  C123        S      3  (32.252, 48.168]
# 4   8.0500   NaN        S      1  (32.252, 48.168]

# %%
Train = Train.drop(['AgeBand'], axis=1)
combine = [Train, Test]
Train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      1
# 1  71.2833   C85        C      3
# 2   7.9250   NaN        S      2
# 3  53.1000  C123        S      3
# 4   8.0500   NaN        S      1

# %%
Train.head()
Barchart('Age')

# %%
for Dataset in combine:
    Dataset['Embarked'] = Dataset['Embarked'].fillna('S')

# %%
Train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      1
# 1  71.2833   C85        C      3
# 2   7.9250   NaN        S      2
# 3  53.1000  C123        S      3
# 4   8.0500   NaN        S      1

# %%
for Dataset in combine:
    Dataset['Embarked'] = Dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} )
Train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  2.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  1.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  1.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# 11           12         1       1    1  3.0      0      0            113783
# 12           13         0       3    0  1.0      0      0         A/5. 2151
# 13           14         0       3    0  2.0      1      5            347082
# 14           15         0       3    1  0.0      0      0            350406
# 15           16         1       2    1  3.0      0      0            248706
# 16           17         0       3    0  0.0      4      1            382652
# 17           18         1       2    0  1.0      0      0            244373
# 18           19         0       3    1  1.0      1      0            345763
# 19           20         1       3    1  2.0      0      0              2649
# 20           21         0       2    0  2.0      0      0            239865
# 21           22         1       2    0  2.0      0      0            248698
# 22           23         1       3    1  0.0      0      0            330923
# 23           24         1       1    0  1.0      0      0            113788
# 24           25         0       3    1  0.0      3      1            349909
# 25           26         1       3    1  2.0      1      5            347077
# 26           27         0       3    0  1.0      0      0              2631
# 27           28         0       1    0  1.0      3      2             19950
# 28           29         1       3    1  1.0      0      0            330959
# 29           30         0       3    0  1.0      0      0            349216
# 30           31         0       1    0  2.0      0      0          PC 17601
# 31           32         1       1    1  2.0      1      0          PC 17569
# 32           33         1       3    1  1.0      0      0            335677
# 33           34         0       2    0  3.0      0      0        C.A. 24579
# 34           35         0       1    0  1.0      1      0          PC 17604
# 35           36         0       1    0  2.0      1      0            113789
# 36           37         1       3    0  1.0      0      0              2677
# 37           38         0       3    0  1.0      0      0        A./5. 2152
# 38           39         0       3    1  1.0      2      0            345764
# 39           40         1       3    1  0.0      1      0              2651
# 40           41         0       3    1  2.0      1      0              7546
# 41           42         0       2    1  1.0      1      0             11668
# 42           43         0       3    0  1.0      0      0            349253
# 43           44         1       2    1  0.0      1      2     SC/Paris 2123
# 44           45         1       3    1  1.0      0      0            330958
# 45           46         0       3    0  1.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  1.0      1      0            370371
# 47           48         1       3    1  1.0      0      0             14311
# 48           49         0       3    0  1.0      2      0              2662
# 49           50         0       3    1  1.0      1      0            349237
#
#         Fare        Cabin  Embarked  Title
# 0     7.2500          NaN         0      1
# 1    71.2833          C85         1      3
# 2     7.9250          NaN         0      2
# 3    53.1000         C123         0      3
# 4     8.0500          NaN         0      1
# 5     8.4583          NaN         2      1
# 6    51.8625          E46         0      1
# 7    21.0750          NaN         0      4
# 8    11.1333          NaN         0      3
# 9    30.0708          NaN         1      3
# 10   16.7000           G6         0      2
# 11   26.5500         C103         0      2
# 12    8.0500          NaN         0      1
# 13   31.2750          NaN         0      1
# 14    7.8542          NaN         0      2
# 15   16.0000          NaN         0      3
# 16   29.1250          NaN         2      4
# 17   13.0000          NaN         0      1
# 18   18.0000          NaN         0      3
# 19    7.2250          NaN         1      3
# 20   26.0000          NaN         0      1
# 21   13.0000          D56         0      1
# 22    8.0292          NaN         2      2
# 23   35.5000           A6         0      1
# 24   21.0750          NaN         0      2
# 25   31.3875          NaN         0      3
# 26    7.2250          NaN         1      1
# 27  263.0000  C23 C25 C27         0      1
# 28    7.8792          NaN         2      2
# 29    7.8958          NaN         0      1
# 30   27.7208          NaN         1      4
# 31  146.5208          B78         1      3
# 32    7.7500          NaN         2      2
# 33   10.5000          NaN         0      1
# 34   82.1708          NaN         1      1
# 35   52.0000          NaN         0      1
# 36    7.2292          NaN         1      1
# 37    8.0500          NaN         0      1
# 38   18.0000          NaN         0      2
# 39   11.2417          NaN         1      2
# 40    9.4750          NaN         0      3
# 41   21.0000          NaN         0      3
# 42    7.8958          NaN         1      1
# 43   41.5792          NaN         1      2
# 44    7.8792          NaN         2      2
# 45    8.0500          NaN         0      1
# 46   15.5000          NaN         2      1
# 47    7.7500          NaN         2      2
# 48   21.6792          NaN         1      1
# 49   17.8000          NaN         0      3

# %%
for dataset in combine:
    dataset['Family'] = dataset['SibSp'] + dataset['Parch'] + 1
Train[['Family']].groupby(['Family']).value_counts()
# Out:
# Family
# 1     537
# 2     161
# 3     102
# 4      29
# 5      15
# 6      22
# 7      12
# 8       6
# 11      7
# Name: count, dtype: int64

# %%
Pclass1st = Train[Train['Pclass'] == 1]['Embarked'].value_counts()
Pclass2nd = Train[Train['Pclass'] == 2]['Embarked'].value_counts()
Pclass3rd = Train[Train['Pclass'] == 3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1st,Pclass2nd,Pclass3rd])
df.index = ['1st','2nd','3rd']
df.plot(kind = 'bar', stacked = True, figsize=(10,5))
plt.show()
print("Pclass1:\n",Pclass1st)
print("Pclass2:\n",Pclass2nd)
print("Pclass3:\n",Pclass3rd)
# Out:
# Pclass1:
#  Embarked
# 0    129
# 1     85
# 2      2
# Name: count, dtype: int64
# Pclass2:
#  Embarked
# 0    164
# 1     17
# 2      3
# Name: count, dtype: int64
# Pclass3:
#  Embarked
# 0    353
# 2     72
# 1     66
# Name: count, dtype: int64

# %%
Train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin  Embarked  Title  Family
# 0   7.2500   NaN         0      1       2
# 1  71.2833   C85         1      3       2
# 2   7.9250   NaN         0      2       1
# 3  53.1000  C123         0      3       2
# 4   8.0500   NaN         0      1       1

# %%
Train["Fare"].fillna(Train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
Test["Fare"].fillna(Test.groupby("Pclass")["Fare"].transform("median"), inplace=True)

# %%
Train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  2.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  1.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  1.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# 11           12         1       1    1  3.0      0      0            113783
# 12           13         0       3    0  1.0      0      0         A/5. 2151
# 13           14         0       3    0  2.0      1      5            347082
# 14           15         0       3    1  0.0      0      0            350406
# 15           16         1       2    1  3.0      0      0            248706
# 16           17         0       3    0  0.0      4      1            382652
# 17           18         1       2    0  1.0      0      0            244373
# 18           19         0       3    1  1.0      1      0            345763
# 19           20         1       3    1  2.0      0      0              2649
# 20           21         0       2    0  2.0      0      0            239865
# 21           22         1       2    0  2.0      0      0            248698
# 22           23         1       3    1  0.0      0      0            330923
# 23           24         1       1    0  1.0      0      0            113788
# 24           25         0       3    1  0.0      3      1            349909
# 25           26         1       3    1  2.0      1      5            347077
# 26           27         0       3    0  1.0      0      0              2631
# 27           28         0       1    0  1.0      3      2             19950
# 28           29         1       3    1  1.0      0      0            330959
# 29           30         0       3    0  1.0      0      0            349216
# 30           31         0       1    0  2.0      0      0          PC 17601
# 31           32         1       1    1  2.0      1      0          PC 17569
# 32           33         1       3    1  1.0      0      0            335677
# 33           34         0       2    0  3.0      0      0        C.A. 24579
# 34           35         0       1    0  1.0      1      0          PC 17604
# 35           36         0       1    0  2.0      1      0            113789
# 36           37         1       3    0  1.0      0      0              2677
# 37           38         0       3    0  1.0      0      0        A./5. 2152
# 38           39         0       3    1  1.0      2      0            345764
# 39           40         1       3    1  0.0      1      0              2651
# 40           41         0       3    1  2.0      1      0              7546
# 41           42         0       2    1  1.0      1      0             11668
# 42           43         0       3    0  1.0      0      0            349253
# 43           44         1       2    1  0.0      1      2     SC/Paris 2123
# 44           45         1       3    1  1.0      0      0            330958
# 45           46         0       3    0  1.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  1.0      1      0            370371
# 47           48         1       3    1  1.0      0      0             14311
# 48           49         0       3    0  1.0      2      0              2662
# 49           50         0       3    1  1.0      1      0            349237
#
#         Fare        Cabin  Embarked  Title  Family
# 0     7.2500          NaN         0      1       2
# 1    71.2833          C85         1      3       2
# 2     7.9250          NaN         0      2       1
# 3    53.1000         C123         0      3       2
# 4     8.0500          NaN         0      1       1
# 5     8.4583          NaN         2      1       1
# 6    51.8625          E46         0      1       1
# 7    21.0750          NaN         0      4       5
# 8    11.1333          NaN         0      3       3
# 9    30.0708          NaN         1      3       2
# 10   16.7000           G6         0      2       3
# 11   26.5500         C103         0      2       1
# 12    8.0500          NaN         0      1       1
# 13   31.2750          NaN         0      1       7
# 14    7.8542          NaN         0      2       1
# 15   16.0000          NaN         0      3       1
# 16   29.1250          NaN         2      4       6
# 17   13.0000          NaN         0      1       1
# 18   18.0000          NaN         0      3       2
# 19    7.2250          NaN         1      3       1
# 20   26.0000          NaN         0      1       1
# 21   13.0000          D56         0      1       1
# 22    8.0292          NaN         2      2       1
# 23   35.5000           A6         0      1       1
# 24   21.0750          NaN         0      2       5
# 25   31.3875          NaN         0      3       7
# 26    7.2250          NaN         1      1       1
# 27  263.0000  C23 C25 C27         0      1       6
# 28    7.8792          NaN         2      2       1
# 29    7.8958          NaN         0      1       1
# 30   27.7208          NaN         1      4       1
# 31  146.5208          B78         1      3       2
# 32    7.7500          NaN         2      2       1
# 33   10.5000          NaN         0      1       1
# 34   82.1708          NaN         1      1       2
# 35   52.0000          NaN         0      1       2
# 36    7.2292          NaN         1      1       1
# 37    8.0500          NaN         0      1       1
# 38   18.0000          NaN         0      2       3
# 39   11.2417          NaN         1      2       2
# 40    9.4750          NaN         0      3       2
# 41   21.0000          NaN         0      3       2
# 42    7.8958          NaN         1      1       1
# 43   41.5792          NaN         1      2       4
# 44    7.8792          NaN         2      2       1
# 45    8.0500          NaN         0      1       1
# 46   15.5000          NaN         2      1       2
# 47    7.7500          NaN         2      2       1
# 48   21.6792          NaN         1      1       3
# 49   17.8000          NaN         0      3       2

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    int64
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     891 non-null    int64
#  11  Title        891 non-null    int64
#  12  Family       891 non-null    int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 90.6+ KB

# %%
for Dataset in combine:
    Dataset.loc[Dataset['Fare'] <= 17, 'Fare'] = 0
    Dataset.loc[(Dataset['Fare'] > 17) & (Dataset['Fare'] <= 30), 'Fare'] = 1
    Dataset.loc[(Dataset['Fare'] > 30) & (Dataset['Fare'] <= 80), 'Fare']   = 2
    Dataset.loc[Dataset['Fare'] > 80, 'Fare'] = 3
    Dataset['Fare'] = Dataset['Fare'].astype(int)

# %%
Train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  2.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  1.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  1.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# 11           12         1       1    1  3.0      0      0            113783
# 12           13         0       3    0  1.0      0      0         A/5. 2151
# 13           14         0       3    0  2.0      1      5            347082
# 14           15         0       3    1  0.0      0      0            350406
# 15           16         1       2    1  3.0      0      0            248706
# 16           17         0       3    0  0.0      4      1            382652
# 17           18         1       2    0  1.0      0      0            244373
# 18           19         0       3    1  1.0      1      0            345763
# 19           20         1       3    1  2.0      0      0              2649
# 20           21         0       2    0  2.0      0      0            239865
# 21           22         1       2    0  2.0      0      0            248698
# 22           23         1       3    1  0.0      0      0            330923
# 23           24         1       1    0  1.0      0      0            113788
# 24           25         0       3    1  0.0      3      1            349909
# 25           26         1       3    1  2.0      1      5            347077
# 26           27         0       3    0  1.0      0      0              2631
# 27           28         0       1    0  1.0      3      2             19950
# 28           29         1       3    1  1.0      0      0            330959
# 29           30         0       3    0  1.0      0      0            349216
# 30           31         0       1    0  2.0      0      0          PC 17601
# 31           32         1       1    1  2.0      1      0          PC 17569
# 32           33         1       3    1  1.0      0      0            335677
# 33           34         0       2    0  3.0      0      0        C.A. 24579
# 34           35         0       1    0  1.0      1      0          PC 17604
# 35           36         0       1    0  2.0      1      0            113789
# 36           37         1       3    0  1.0      0      0              2677
# 37           38         0       3    0  1.0      0      0        A./5. 2152
# 38           39         0       3    1  1.0      2      0            345764
# 39           40         1       3    1  0.0      1      0              2651
# 40           41         0       3    1  2.0      1      0              7546
# 41           42         0       2    1  1.0      1      0             11668
# 42           43         0       3    0  1.0      0      0            349253
# 43           44         1       2    1  0.0      1      2     SC/Paris 2123
# 44           45         1       3    1  1.0      0      0            330958
# 45           46         0       3    0  1.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  1.0      1      0            370371
# 47           48         1       3    1  1.0      0      0             14311
# 48           49         0       3    0  1.0      2      0              2662
# 49           50         0       3    1  1.0      1      0            349237
#
#     Fare        Cabin  Embarked  Title  Family
# 0      0          NaN         0      1       2
# 1      2          C85         1      3       2
# 2      0          NaN         0      2       1
# 3      2         C123         0      3       2
# 4      0          NaN         0      1       1
# 5      0          NaN         2      1       1
# 6      2          E46         0      1       1
# 7      1          NaN         0      4       5
# 8      0          NaN         0      3       3
# 9      2          NaN         1      3       2
# 10     0           G6         0      2       3
# 11     1         C103         0      2       1
# 12     0          NaN         0      1       1
# 13     2          NaN         0      1       7
# 14     0          NaN         0      2       1
# 15     0          NaN         0      3       1
# 16     1          NaN         2      4       6
# 17     0          NaN         0      1       1
# 18     1          NaN         0      3       2
# 19     0          NaN         1      3       1
# 20     1          NaN         0      1       1
# 21     0          D56         0      1       1
# 22     0          NaN         2      2       1
# 23     2           A6         0      1       1
# 24     1          NaN         0      2       5
# 25     2          NaN         0      3       7
# 26     0          NaN         1      1       1
# 27     3  C23 C25 C27         0      1       6
# 28     0          NaN         2      2       1
# 29     0          NaN         0      1       1
# 30     1          NaN         1      4       1
# 31     3          B78         1      3       2
# 32     0          NaN         2      2       1
# 33     0          NaN         0      1       1
# 34     3          NaN         1      1       2
# 35     2          NaN         0      1       2
# 36     0          NaN         1      1       1
# 37     0          NaN         0      1       1
# 38     1          NaN         0      2       3
# 39     0          NaN         1      2       2
# 40     0          NaN         0      3       2
# 41     1          NaN         0      3       2
# 42     0          NaN         1      1       1
# 43     2          NaN         1      2       4
# 44     0          NaN         2      2       1
# 45     0          NaN         0      1       1
# 46     0          NaN         2      1       2
# 47     0          NaN         2      2       1
# 48     1          NaN         1      1       3
# 49     1          NaN         0      3       2

# %%
Train["Title"].fillna(Train.groupby("Pclass")["Title"].transform("median"), inplace=True)
Test["Title"].fillna(Test.groupby("Pclass")["Title"].transform("median"), inplace=True)

# %%
Train.shape,Test.shape
# Out:
# ((891, 13), (418, 12))

# %%
Train = Train.drop(['Ticket', 'Cabin','PassengerId'], axis=1)
Test = Test.drop(['Ticket', 'Cabin'], axis=1)

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    int32
#  7   Embarked  891 non-null    int64
#  8   Title     891 non-null    int64
#  9   Family    891 non-null    int64
# dtypes: float64(1), int32(1), int64(8)
# memory usage: 66.3 KB

# %%
Train.head(100)
# Out:
#     Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked  Title  Family
# 0          0       3    0  1.0      1      0     0         0      1       2
# 1          1       1    1  2.0      1      0     2         1      3       2
# 2          1       3    1  1.0      0      0     0         0      2       1
# 3          1       1    1  2.0      1      0     2         0      3       2
# 4          0       3    0  2.0      0      0     0         0      1       1
# ..       ...     ...  ...  ...    ...    ...   ...       ...    ...     ...
# 95         0       3    0  1.0      0      0     0         0      1       1
# 96         0       1    0  3.0      0      0     2         1      1       1
# 97         1       1    0  1.0      0      1     2         1      1       2
# 98         1       2    1  2.0      0      1     1         0      3       2
# 99         0       2    0  2.0      1      0     1         0      1       2
#
# [100 rows x 10 columns]

# %%
Train.shape,Test.shape
# Out:
# ((891, 10), (418, 10))

# %%
Test.head(420)
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked  Title  \
# 0            892       3    0  2.0      0      0     0         2    1.0
# 1            893       3    1  2.0      1      0     0         0    3.0
# 2            894       2    0  3.0      0      0     0         2    1.0
# 3            895       3    0  1.0      0      0     0         0    1.0
# 4            896       3    1  1.0      1      1     0         0    3.0
# ..           ...     ...  ...  ...    ...    ...   ...       ...    ...
# 413         1305       3    0  1.0      0      0     0         0    1.0
# 414         1306       1    1  2.0      0      0     3         1    2.0
# 415         1307       3    0  2.0      0      0     0         0    1.0
# 416         1308       3    0  1.0      0      0     0         0    1.0
# 417         1309       3    0  0.0      1      1     1         1    4.0
#
#      Family
# 0         1
# 1         2
# 2         1
# 3         1
# 4         3
# ..      ...
# 413       1
# 414       1
# 415       1
# 416       1
# 417       3
#
# [418 rows x 10 columns]

# %%
Train.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.352413    1.291807    0.523008    0.381594
# std      0.486592    0.836071    0.477990    0.789062    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    1.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000    1.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000    2.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000    3.000000    8.000000    6.000000
#
#              Fare    Embarked       Title      Family
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.789001    0.361392    1.710438    1.904602
# std      1.012468    0.635673    0.968778    1.613459
# min      0.000000    0.000000    1.000000    1.000000
# 25%      0.000000    0.000000    1.000000    1.000000
# 50%      0.000000    0.000000    1.000000    1.000000
# 75%      2.000000    1.000000    2.000000    2.000000
# max      3.000000    2.000000    4.000000   11.000000

# %% [markdown]
# Model Evaluation

# %%
Train.Family.value_counts()
# Out:
# Family
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %% [markdown]
# Data Modelling using Different ML Methods

# %%
X_train = Train.drop("Survived", axis=1)
Y_train = Train["Survived"]
X_test  = Test.drop("PassengerId", axis=1).copy()
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 9), (891,), (418, 9))

# %%
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
acc_log = round(logreg.score(X_train, Y_train) * 100, 2)
acc_log
# Out:
# 81.26

# %%
dfCoe = pd.DataFrame(Train.columns.delete(0))
dfCoe.columns = ['Feature']
dfCoe["Correlation"] = pd.Series(logreg.coef_[0])

dfCoe.sort_values(by='Correlation', ascending=False)
# Out:
#     Feature  Correlation
# 1       Sex     2.107892
# 7     Title     0.681688
# 5      Fare     0.355533
# 6  Embarked     0.188851
# 4     Parch    -0.029998
# 3     SibSp    -0.243220
# 8    Family    -0.273426
# 2       Age    -0.557661
# 0    Pclass    -0.794661

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train, Y_train) * 100, 2)
acc_knn
# Out:
# 85.52

# %%
svc = SVC()
svc.fit(X_train, Y_train)
Y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train, Y_train) * 100, 2)
acc_svc
# Out:
# 83.28

# %%
Frame = pd.DataFrame({
    'Label': ['Support Vector Machines', 'KNN', 'Logistic Regression'],
    'Score': [acc_svc, acc_knn, acc_log]})
Frame.sort_values(by='Score', ascending=False)
# Out:
#                      Label  Score
# 1                      KNN  85.52
# 0  Support Vector Machines  83.28
# 2      Logistic Regression  81.26

# %%
Survival = pd.DataFrame({
        "PassengerId": Test["PassengerId"],
        "Survived": Y_pred
    })
Survival
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
Survival.to_csv('Titanic.csv')

# %%
pip install -U notebook-as-pdf
# Out:
# Collecting notebook-as-pdf
#   Downloading notebook_as_pdf-0.5.0-py3-none-any.whl (6.5 kB)
# Requirement already satisfied: nbconvert in c:\users\mohit tarade\anaconda3\lib\site-packages (from notebook-as-pdf) (6.5.4)
# Collecting pyppeteer (from notebook-as-pdf)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ---------------------------------------- 0.0/83.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/83.4 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/83.4 kB ? eta -:--:--
#      -------------- ----------------------- 30.7/83.4 kB 435.7 kB/s eta 0:00:01
#      ---------------------------- --------- 61.4/83.4 kB 465.5 kB/s eta 0:00:01
#      -------------------------------------- 83.4/83.4 kB 585.1 kB/s eta 0:00:00
# Collecting PyPDF2 (from notebook-as-pdf)
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/232.6 kB 660.6 kB/s eta 0:00:01
#      ------ ------------------------------ 41.0/232.6 kB 653.6 kB/s eta 0:00:01
#      ----------- ------------------------- 71.7/232.6 kB 491.5 kB/s eta 0:00:01
#      ------------------- ---------------- 122.9/232.6 kB 722.1 kB/s eta 0:00:01
#      -------------------------- --------- 174.1/232.6 kB 807.1 kB/s eta 0:00:01
#      ---------------------------------- - 225.3/232.6 kB 860.2 kB/s eta 0:00:01
#      ------------------------------------ 232.6/232.6 kB 889.3 kB/s eta 0:00:00
# Requirement already satisfied: lxml in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (4.12.2)
# Requirement already satisfied: bleach in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.4)
# Requirement already satisfied: jinja2>=3.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (5.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.5.13)
# Requirement already satisfied: nbformat>=5.1 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (5.9.2)
# Requirement already satisfied: packaging in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (2.15.1)
# Requirement already satisfied: tinycss2 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (1.2.1)
# Requirement already satisfied: traitlets>=5.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (5.7.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (1.4.4)
# Requirement already satisfied: certifi>=2021 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (6.0.0)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer->notebook-as-pdf)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (1.26.16)
# Collecting websockets<11.0,>=10.0 (from pyppeteer->notebook-as-pdf)
#   Downloading websockets-10.4-cp311-cp311-win_amd64.whl (101 kB)
#      ---------------------------------------- 0.0/101.4 kB ? eta -:--:--
#      ----------------------- --------------- 61.4/101.4 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 101.4/101.4 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\mohit tarade\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer->notebook-as-pdf) (3.11.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert->notebook-as-pdf) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jupyter-core>=4.7->nbconvert->notebook-as-pdf) (305.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert->notebook-as-pdf) (7.4.9)
# Requirement already satisfied: nest-asyncio in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert->notebook-as-pdf) (1.5.6)
# Requirement already satisfied: fastjsonschema in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->notebook-as-pdf) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mohit tarade\anaconda3\lib\site-packages (from nbformat>=5.1->nbconvert->notebook-as-pdf) (4.17.3)
# Requirement already satisfied: colorama in c:\users\mohit tarade\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer->notebook-as-pdf) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mohit tarade\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook-as-pdf) (2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from bleach->nbconvert->notebook-as-pdf) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\mohit tarade\anaconda3\lib\site-packages (from bleach->nbconvert->notebook-as-pdf) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->notebook-as-pdf) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->notebook-as-pdf) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert->notebook-as-pdf) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert->notebook-as-pdf) (23.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\mohit tarade\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert->notebook-as-pdf) (6.3.2)
# Installing collected packages: pyee, websockets, PyPDF2, pyppeteer, notebook-as-pdf
# Successfully installed PyPDF2-3.0.1 notebook-as-pdf-0.5.0 pyee-8.2.2 pyppeteer-1.0.2 websockets-10.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyppeteer
# Out:
# Requirement already satisfied: pyppeteer in c:\users\mohit tarade\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (1.4.4)
# Requirement already satisfied: certifi>=2021 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (6.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (1.26.16)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\mohit tarade\anaconda3\lib\site-packages (from pyppeteer) (10.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\mohit tarade\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer) (3.11.0)
# Requirement already satisfied: colorama in c:\users\mohit tarade\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Thank You.....
